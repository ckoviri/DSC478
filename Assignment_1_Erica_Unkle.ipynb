# %%
import numpy as np
import pandas as pd
import os
## Set up matplotlib to work interactively.
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir('C:\\Users\\erica\OneDrive - DePaul University\\OneDrive - DePaul University\\01 Current Classes\\DSC478 - Machine Programming')

# %%
bank_df = pd.read_csv("bank_data.csv", sep=',')
bank_df.head(10)
# Out:
#         id  age    income  children  gender      region married  car  \
# 0  ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# 1  ID12102   40  30085.10         3    MALE        TOWN     YES  YES
# 2  ID12103   51  16575.40         0  FEMALE  INNER_CITY     YES  YES
# 3  ID12104   23  20375.40         3  FEMALE        TOWN     YES   NO
# 4  ID12105   57  50576.30         0  FEMALE       RURAL     YES   NO
# 5  ID12106   57  37869.60         2  FEMALE        TOWN     YES   NO
# 6  ID12107   22   8877.07         0    MALE       RURAL      NO   NO
# 7  ID12108   58  24946.60         0    MALE        TOWN     YES  YES
# 8  ID12109   37  25304.30         2  FEMALE    SUBURBAN     YES  YES
# 9  ID12110   54  24212.10         2    MALE        TOWN     YES  YES
#
#   savings_acct current_acct mortgage  pep
# 0           NO           NO       NO  YES
# 1           NO          YES      YES   NO
# 2          YES          YES       NO   NO
# ...

# %%
bank_df.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
plotg = bank_df.groupby('gender').size().plot(kind='bar')
plotg.set_xlabel('Gender')
plotg.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotc = bank_df.groupby('car').size().plot(kind='bar')
plotc.set_xlabel('car')
plotc.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotm = bank_df.groupby('married').size().plot(kind='bar')
plotm.set_xlabel('married')
plotm.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotsa = bank_df.groupby('savings_acct').size().plot(kind='bar')
plotsa.set_xlabel('savings_acct')
plotsa.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotpep = bank_df.groupby('pep').size().plot(kind='bar')
plotpep.set_xlabel('pep')
plotpep.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotmt = bank_df.groupby('mortgage').size().plot(kind='bar')
plotmt.set_xlabel('mortgage')
plotmt.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotca = bank_df.groupby('current_acct').size().plot(kind='bar')
plotca.set_xlabel('current_acct')
plotca.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
plotrg = bank_df.groupby('region').size().plot(kind='bar')
plotrg.set_xlabel('region')
plotrg.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# ## 2. PEP vs no PEP

# %%
##Save all instances where pep= 'yes' into separate df (pep_yes_df)
pep_yes = (bank_df["pep"]=='YES')
pep_yes_df = bank_df[pep_yes]

# %%
pep_yes_df.describe()
# Out:
#               age        income    children
# count  274.000000    274.000000  274.000000
# mean    45.127737  30644.919453    0.945255
# std     14.327991  13609.613043    0.860571
# min     18.000000   7756.360000    0.000000
# 25%     34.000000  19639.475000    0.000000
# 50%     45.000000  28080.050000    1.000000
# 75%     58.000000  38458.350000    1.000000
# max     67.000000  63130.100000    3.000000

# %%
pep_no = (bank_df["pep"]=='NO')
pep_no_df = bank_df[pep_no]

# %%
pep_no_df.describe()
# Out:
#               age        income    children
# count  326.000000    326.000000  326.000000
# mean    40.098160  24900.953374    1.067485
# std     14.123506  11661.123422    1.195524
# min     18.000000   5014.210000    0.000000
# 25%     27.000000  15366.475000    0.000000
# 50%     40.000000  23105.000000    0.000000
# 75%     51.000000  31210.900000    2.000000
# max     67.000000  61554.600000    3.000000

# %% [raw]
# The mean age for users with no PEP is 40 while the mean age for users that do purchase PEP is  45.  Customers that buy pep also have a higher mean income and fewer children than customers who do not purchase PEP.

# %%
plot1 = pd.crosstab(bank_df['gender'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %%
plot1 = pd.crosstab(bank_df['car'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %%
plot1 = pd.crosstab(bank_df['married'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %%
plot1 = pd.crosstab(bank_df['savings_acct'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %%
plot1 = pd.crosstab(bank_df['current_acct'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %%
plot1 = pd.crosstab(bank_df['region'], bank_df['pep']).plot(kind='bar')
plot1.set_ylabel("Frequency")
plt.show(plot1)

# %% [raw]
# Customers who live in town or inner city and who have a current account are more likely to not buy PEP. Couples who are married are more liekly to not purchase PEP.  Whether you are male or female or own a cr or not, does not have much effect on if you buy PEP or not.

# %% [markdown]
# ## 3.Use z-score normalization to standardize the values of the income attribute.

# %%
income_mean = bank_df['income'].mean()
income_std = bank_df['income'].std()
income_znorm = (bank_df['income'] - income_mean) / income_std
income_znorm.head(10)
# Out:
# 0   -0.773523
# 1    0.198541
# 2   -0.848766
# 3   -0.554180
# 4    1.787071
# 5    0.802015
# 6   -1.445560
# 7   -0.199809
# 8   -0.172079
# 9   -0.256749
# Name: income, dtype: float64

# %% [markdown]
# ## 4.Discretize the age attribute into 3 categories (corresponding to "young", "mid-age", and "old").

# %%
# age_bins = pd.qcut(bank_df.age, 3)
age_bins = pd.qcut(bank_df.age, [0, .33, .66, 1], labels=["young", "mid-age", "old"], retbins=True)
age_bins
# Out:
# (0      mid-age
#  1      mid-age
#  2          old
#  3        young
#  4          old
#  5          old
#  6        young
#  7          old
#  8      mid-age
#  9          old
#  10         old
#  11         old
#  12     mid-age
#  13         old
#  14     mid-age
#  15     mid-age
#  16     mid-age
#  17     mid-age
#  18         old
#  19       young
#  20         old
#  21         old
#  22         old
#  23       young
#  24       young
#  25         old
#  26     mid-age
#  27     mid-age
#  28     mid-age
#  29         old
#          ...
#  570    mid-age
#  571    mid-age
#  572      young
#  573    mid-age
#  574    mid-age
#  575    mid-age
#  576      young
#  577        old
#  578      young
#  579    mid-age
#  580        old
#  581      young
#  582    mid-age
#  583    mid-age
#  584      young
#  585      young
#  586      young
#  587    mid-age
#  588        old
#  589      young
#  590      young
#  591    mid-age
#  592    mid-age
#  593        old
# ...

# %% [markdown]
# ## 5.Use Min-Max Normalization to transform the values of all numeric attributes (income, age, children) in the original table (before the transforamtions in parts 3 and 4 above) onto the range 0.0-1.0.

# %%
bank_norm = bank_df
min_income = bank_norm['income'].min()
max_income = bank_norm['income'].max()
bank_norm['income'] = (bank_norm["income"] - min_income) / (max_income-min_income)
bank_norm.head(10)
# Out:
#         id  age    income  children  gender      region married  car  \
# 0  ID12101   48  0.215634         1  FEMALE  INNER_CITY      NO   NO
# 1  ID12102   40  0.431395         3    MALE        TOWN     YES  YES
# 2  ID12103   51  0.198933         0  FEMALE  INNER_CITY     YES  YES
# 3  ID12104   23  0.264320         3  FEMALE        TOWN     YES   NO
# 4  ID12105   57  0.783987         0  FEMALE       RURAL     YES   NO
# 5  ID12106   57  0.565343         2  FEMALE        TOWN     YES   NO
# 6  ID12107   22  0.066468         0    MALE       RURAL      NO   NO
# 7  ID12108   58  0.342977         0    MALE        TOWN     YES  YES
# 8  ID12109   37  0.349132         2  FEMALE    SUBURBAN     YES  YES
# 9  ID12110   54  0.330338         2    MALE        TOWN     YES  YES
#
#   savings_acct current_acct mortgage  pep
# 0           NO           NO       NO  YES
# 1           NO          YES      YES   NO
# 2          YES          YES       NO   NO
# ...

# %%
norm_age =  (bank_df2["age"] - bank_df2['age'].min()) / (bank_df2['age'].max()-bank_df2['age'].min())
bank_df2['age'] = norm_age
bank_df2.head(10)
# Out:
#         id       age    income  children  gender      region married  car  \
# 0  ID12101  0.612245  0.215634         1  FEMALE  INNER_CITY      NO   NO
# 1  ID12102  0.448980  0.431395         3    MALE        TOWN     YES  YES
# 2  ID12103  0.673469  0.198933         0  FEMALE  INNER_CITY     YES  YES
# 3  ID12104  0.102041  0.264320         3  FEMALE        TOWN     YES   NO
# 4  ID12105  0.795918  0.783987         0  FEMALE       RURAL     YES   NO
# 5  ID12106  0.795918  0.565343         2  FEMALE        TOWN     YES   NO
# 6  ID12107  0.081633  0.066468         0    MALE       RURAL      NO   NO
# 7  ID12108  0.816327  0.342977         0    MALE        TOWN     YES  YES
# 8  ID12109  0.387755  0.349132         2  FEMALE    SUBURBAN     YES  YES
# 9  ID12110  0.734694  0.330338         2    MALE        TOWN     YES  YES
#
#   savings_acct current_acct mortgage  pep
# 0           NO           NO       NO  YES
# 1           NO          YES      YES   NO
# ...

# %%
norm_children =  (bank_df2["children"] - bank_df2['children'].min()) / (bank_df2['children'].max()-bank_df2['children'].min())
bank_df2['children'] = norm_children

# %% [markdown]
# ## 6. Convert the table (after normalization in part 5) into the standard spreadsheet format.

# %%
bank_df3 = bank_df2.drop("id", axis=1)
bank_dummies = pd.get_dummies(bank_df3)
bank_dummies.head(10)
# Out:
#         age    income  children  gender_FEMALE  gender_MALE  \
# 0  0.612245  0.215634  0.333333              1            0
# 1  0.448980  0.431395  1.000000              0            1
# 2  0.673469  0.198933  0.000000              1            0
# 3  0.102041  0.264320  1.000000              1            0
# 4  0.795918  0.783987  0.000000              1            0
# 5  0.795918  0.565343  0.666667              1            0
# 6  0.081633  0.066468  0.000000              0            1
# 7  0.816327  0.342977  0.000000              0            1
# 8  0.387755  0.349132  0.666667              1            0
# 9  0.734694  0.330338  0.666667              0            1
#
#    region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  married_NO  \
# 0                  1             0                0            0           1
# 1                  0             0                0            1           0
# ...

# %%
##Save to file bank_numeric
bank_dummies.to_csv("bank_numeric2.csv", float_format="%1.2f")

# %% [markdown]
# ## 7. perform basic correlation analysis among the attributes

# %%
bank_dummies.corr()
# Out:
#                         age    income  children  gender_FEMALE  gender_MALE  \
# age                1.000000  0.752726  0.023572       0.090081    -0.090081
# income             0.752726  1.000000  0.036761       0.023845    -0.023845
# children           0.023572  0.036761  1.000000       0.014206    -0.014206
# gender_FEMALE      0.090081  0.023845  0.014206       1.000000    -1.000000
# gender_MALE       -0.090081 -0.023845 -0.014206      -1.000000     1.000000
# region_INNER_CITY -0.025171 -0.047564 -0.051222      -0.023459     0.023459
# region_RURAL       0.018635  0.084776  0.089902      -0.009092     0.009092
# region_SUBURBAN    0.031345  0.029824 -0.014122      -0.010951     0.010951
# region_TOWN       -0.008510 -0.036431 -0.007033       0.040472    -0.040472
# married_NO        -0.010394  0.008386  0.048716       0.021110    -0.021110
# married_YES        0.010394 -0.008386 -0.048716      -0.021110     0.021110
# ...

# %% [markdown]
# Income and age have a fairly positive correlation.

# %% [markdown]
# ## 8. create a scatter plot of the (non-normalized) Income attribute relative to Age

# %%
bank_df = pd.read_csv("bank_data.csv", sep=',')
bank_df.plot(x="income", y="age", kind="scatter")
plt.ylabel('Age')
plt.xlabel('Income')
plt.title('Income vs Age Scatterplot')
# Out:
# Text(0.5,1,'Income vs Age Scatterplot')

# %% [markdown]
# Income and age seem to be fairly postivily correlated. As income increass, age increases.

# %% [markdown]
# ## 9.Create histograms for (non-normalized) Income (using 9 bins) and Age (using 15 bins).

# %%
## Histogram with legend, axis labels, title, and grid
plt.hist(bank_df["income"], bins=9, alpha=0.5)
plt.xlabel('income')
plt.ylabel('Count')
plt.title('Histogram of Income')
# Out:
# Text(0.5,1,'Histogram of Income')

# %%
plt.hist(bank_df["age"], bins=15, alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age')
# Out:
# Text(0.5,1,'Histogram of Age')

# %% [markdown]
# ## 10.Using a bar graph, plot the distribution of the values of the region attribute

# %%
regionplot =  bank_df.groupby('region').size().plot(kind='bar')

# %% [markdown]
# ## 11. Perform a cross-tabulation of the region attribute with the pep attribute

# %%
pep_yes = (bank_df["pep"]=='YES')
pep_yes_df = bank_df[pep_yes]
pep_no = (bank_df["pep"]=='NO')
pep_no_df = bank_df[pep_no]

region_plot = pd.crosstab(bank_df['region'], bank_df['pep']).plot(kind='bar')
region_plot.set_ylabel("Frequency")
plt.show(region_plot)
